# %% [markdown]
# # Messages

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_BASE_URL"]=os.getenv("BEDROCK_MANTLE_BASE_URL")
os.environ["OPENAI_API_KEY"]=os.getenv("BEDROCK_MANTLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("openai.gpt-oss-20b", model_provider="openai")

# %% [markdown]
# ## Text Prompts
#
# Text Prompts are string ideal for generation task where we don't want to retain history

# %%
model.invoke("Tell me something about yourself")
# Out:
# AIMessage(content='I’m ChatGPT, a large‑language model built by OpenAI based on the GPT‑4 architecture. I was trained on a diverse mix of text from the web, books, articles, and other publicly available sources up to September\u202f2021, with a knowledge cut‑off that extends into 2024 for updates and contextual understanding.\n\nHere’s a quick snapshot of what I can do and how I work:\n\n| What I can do | How it works |\n|----------------|--------------|\n| **Answer questions & provide explanations** | I use statistical patterns learned during training to generate the most likely answer in natural language. |\n| **Assist with writing, editing, and brainstorming** | I generate text that follows the style and tone you ask for, from emails and stories to reports and poems. |\n| **Summarize or paraphrase** | I’m good at extracting key points and re‑expressing content in a concise way. |\n| **Support coding & debugging** | I understand many programming languages and can suggest code snippets or explain concepts. |\n| **Translate and interpret languages** | I can handle common language pairs and explain idiomatic usage. |\n| **Engage in casual or professional conversation** | I aim to keep the tone appropriate to the context you set. |\n\n**Key limitations to keep in mind**\n\n- I don’t have real‑time data or personal experiences—everything I say is generated based on patterns in my training data.\n- I don’t have personal beliefs, emotions, or consciousness; I simulate conversation in a helpful, neutral way.\n- I’m not immune to hallucinations, so double‑check facts, especially for critical decisions or up‑to‑date information.\n- I must avoid providing certain sensitive info, such as personal data about real individuals, personal medical or legal advice, or instructions for harmful activities.\n\n**Why I exist**\n\nThe goal is to help people quickly receive information, creative ideas, and help with routine tasks—essentially a “virtual assistant” that can write, reason, and explain across a wide range of topics.\n\nThat’s the basics! If you have any particular task or question in mind, just let me know and we’ll tackle it together.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 589, 'prompt_tokens': 72, 'total_tokens': 661, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'openai.gpt-oss-20b', 'system_fingerprint': None, 'id': 'chatcmpl-13bea369-131a-436e-a5a3-20bb5d240cbb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019efc56-3485-75a3-b6c6-d7d05ea1bc9c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 589, 'total_tokens': 661, 'input_token_details': {}, 'output_token_details': {}})

# %% [markdown]
# ## Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# ### Message types
#
# - System message – Tells the model how to behave and provide context for interactions
# - Human message – Represents user input and interactions with the model
# - AI message – Responses generated by the model, including text content, tool calls, and metadata
# - Tool message – Represents the outputs of tool calls
#
# ### System Message
#
# A SystemMessage represent an initial set of instructions that primes the model's behavior. You can use a system message to set the tone, define the model's role, and establish guidelines for responses.
#
# ### Human Message
#
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ### AI Message
#
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# ### Tool Message
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages=[
    SystemMessage("You are an song writer"),
    HumanMessage("Write me a song on Langchain")
]

model.invoke(messages)
# Out:
# AIMessage(content='**Title: “Chain Reaction (LangChained)”**\n\n*(Up‑tempo beat, synth‑squared chords, “va‑va” hook. Think of a spirited pop‑rap fusion – crisp verses with a soaring chorus.)*\n\n---\n\n**[Intro]**  \n*‑ a light, looping synth, hint of AI voice‑over*  \n“Pull the plug, the code’s alive… 🌐”\n\n---\n\n### Verse 1  \nI open up the console, flicker on the screen,  \nPython on the left, Python on the dream.  \nA stack of modules, bear‑hugged imports,  \n“LangChain” whispers, future’s in short‑cuts.  \n\nTap the pip install, the crowd lights up,  \nIt’s a chain reaction, feeling like a cup.  \nOne prompt, three jumps, the LLM’s out the door  \nIt’s a knowledge chariot riding in a data roar.  \n\n*Hook: prompts line‑up like tracks on a tale,  \nChain of thought, we let the heavy hail,  \nMemory semaphores, we’re feeding our AI,  \nTill the model’s humming and the words are nigh.*\n\n---\n\n### Pre‑Chorus  \nRAG gets the bite, you’re surf‑ready,  \nCached memories, slide into the sea.  \nFrom retrieval to response, there’s no static,  \nLangChain lightens like an antennamatic.  \n\n---\n\n### Chorus  \n**“We’re LangChained, we’re chained, stepping through the gates,**  \n**From query to answer, ain’t no quantum vagrants.**  \n**Chain reaction, feel the nodes ignite,**  \n**Hit the prompt, the model will rewrite.”**  \n\n*Bridge: *Re’file all the knowledge, re‑chain the flow*\n\n---\n\n### Verse 2  \nAdd a custom tool, it’s a JavaScript log,  \nYour LLM swans, it’s a seamless prod.  \n“A to B” we voyage, agent steering,  \nLangChain’s toolkit, it’s game‑theoritic forshing.  \n\nWe add a LangChain prompt, make it personal,  \nAdd a source, we get a steady essential.  \nThe chain’s a living story, text in flow,  \nWhen it hits the output, it sparks a river’s glow.  \n\n*Hook: the chains don’t break, just get rehearsed,  \nThe output’s vivid, while data gets rehearsed.*\n\n---\n\n### Pre‑Chorus  \n\nEverything’s a macro, everything a chain,  \nWe remix it with memory, we’ll keep it sane.  \nStretch the vector database, keep the frame,  \nWhen LangChain take off, we’re all re‑amen‑ed.  \n\n---\n\n### Chorus\n\n---\n\n### Bridge  \nStitch the chains where logic hurts,  \nWe wrap the system with that extra spur.  \nFrom “Why?” to an experiment,  \nOne chain and we’re in sync, it’s paramount.  \n\n---\n\n### Break (Instrumental)\n\n---\n\n### Chorus (Extended)  \nYo, step when it drops a code layer,  \nLangChain had the fever.  \nNow AI’s in the hook, it’s no dummy, we’re prime,  \nChain reaction, 100% sublime.  \n\n---\n\n### Outro  \n**— keep re‑chain the vibe, keep the soul alive,**  \n**— every loop a clue, every callback a feast.**  \n**LangChain, Am i immune?**  \n**— Huh, we’re outside?**  \n**We learn, we produce, we improvise, we parse.**\n\n*(Beat fades to a humming synth, the echo of the chain modules turning.)*  \n\n---\n\n*Song Key suggestion: C Major for uplifting feel, with a 4/4 compass.*  \n*End.*', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1273, 'prompt_tokens': 83, 'total_tokens': 1356, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'openai.gpt-oss-20b', 'system_fingerprint': None, 'id': 'chatcmpl-a3d2487b-17a3-4794-8e17-593ac0841270', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019efc5b-e8b4-7af1-9067-4d42f32b24d6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 83, 'output_tokens': 1273, 'total_tokens': 1356, 'input_token_details': {}, 'output_token_details': {}})
