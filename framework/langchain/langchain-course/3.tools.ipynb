# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_BASE_URL"]=os.getenv("BEDROCK_MANTLE_BASE_URL")
os.environ["OPENAI_API_KEY"]=os.getenv("BEDROCK_MANTLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("openai.gpt-oss-20b", model_provider="openai")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11', 'langchain-openai': '1.3.3'}}, output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x112467cb0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x1126a8830>, root_client=<openai.OpenAI object at 0x11181af90>, root_async_client=<openai.AsyncOpenAI object at 0x1126a8590>, model_name='openai.gpt-oss-20b', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_chunk_timeout=120.0)

# %%
from langchain.tools import tool

@tool
def get_weather(location:str)-> str:
    """Get weather of a location"""
    return f"The weather {location} is sunny."

model_with_tools = model.bind_tools([get_weather])

# %%
model_with_tools.invoke("How is weather in Delhi today?")
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 126, 'total_tokens': 178, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'openai.gpt-oss-20b', 'system_fingerprint': None, 'id': 'chatcmpl-dca8e245-d4a8-4919-a208-ea8b9a4f45b7', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019efa7d-bbaf-7f43-9302-785105a63435-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Delhi'}, 'id': 'chatcmpl-tool-8ed99689453aed1e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 126, 'output_tokens': 52, 'total_tokens': 178, 'input_token_details': {}, 'output_token_details': {}})

# %% [markdown]
# ## Tool Execution Loops
